# %%
from auto_drive_functions import retrieve_angle 
from PIL import Image,ImageOps,ImageFilter
from ImageFrame import Frame
import timeit as ti
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
from EdgeFinderV1 import EdgeFinder as ef

# %%
img = Image.open('img3.jpg')
img = ImageOps.grayscale(img)
img = img.filter(ImageFilter.GaussianBlur(1))

# %%
img = np.array(img)
img.shape
# Out:
# (480, 640)

# %%
frame1 = Frame(640,480,10)
# Out:
# load CVS file successfully

# %%
data = frame1.get_data(img,5)

# %%
for key in data.keys():
    line1 = ef(30,3,data[key])
    
    line1.plot_data(lines=key)

# %%
plt.axis([0.0,640,0.0,480])
for key in frame1.lines_frame.keys():
    plt.plot(frame1.lines_frame[key][:,0],frame1.lines_frame[key][:,1],'ro')

# %%
starttime = ti.default_timer()
angle = retrieve_angle(40,3,img,frame1)
print(ti.default_timer()-starttime)
# Out:
# nan
# nan
# 100
# nan
# 127
# nan
# 139
# nan
# 160
# nan
# edges:  {'L2': 100, 'L3': 127, 'L4': 139, 'L5': 160, 'side': 0}
# 0.22526230000000425

# %%
print(angle[0])
points = angle[0]
# Out:
# [[597. 379.]
#  [597. 320.]
#  [588. 255.]
#  [581. 169.]]

# %%
plt.axis([0.0,640,0.0,480])
gray()
imshow(img)
plt.plot(640/2,480,'ro')
plt.plot(points[:,0],points[:,1],'bo')
show()
